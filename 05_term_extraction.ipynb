# %%
import os
import pandas as pd
import numpy as np

# %%
BASE = "/home/usertp/FDT/sf_FDT/CorpusARIA/TERMYT"

# %%
rows = []

for event in sorted(os.listdir(BASE)):
    raw_dir = os.path.join(BASE, event, "default-ann", "raw")
    term_file = os.path.join(raw_dir, "termList.txt")

    if os.path.exists(term_file):

        # Lecture brute du fichier à colonnes multiples
        df = pd.read_csv(
            term_file,
            sep="\t",
            header=None,
            engine="python",
            quoting=3
        )

        # Colonne 1 = vrai terme (colonne 0 = ID inutile)
        df["term"] = df[1].astype(str)

        # Filtrer "Head", "nan", etc.
        df = df[df["term"].str.lower() != "head"]
        df = df[df["term"].str.lower() != "nan"]

        # ❗ IMPORTANT : filtrer tous les termes numériques
        df = df[~df["term"].str.match(r"^\d+$")]             # ex: "40"
        df = df[df["term"].str.contains("[A-Za-zÀ-ÿ]")]      # garder termes linguistiques

        # Ajouter l'évènement
        df["event"] = event

        # On ne garde que la structure minimale
        rows.append(df[["event", "term"]])

# Fusion finale
df_all = pd.concat(rows, ignore_index=True)

df_all.head()
# Out:
#      event                                 term
# 0  event-0                      Lemmatised form
# 1  event-0                  orientation du pale
# 2  event-0             bloc de frein du système
# 3  event-0                        bloc de frein
# 4  event-0  limite de conception de le éolienne

# %%
df_all["term"].unique()[:50]
# Out:
# array(['Lemmatised form', 'orientation du pale',
#        'bloc de frein du système', 'bloc de frein',
#        'limite de conception de le éolienne',
#        'contrôle annuels.Les autre éolienne du site',
#        'protocole du inspection de maintenance',
#        'système de contrôle du pale', 'expertise de le éolien mise',
#        'partie du bloc de frein', 'autre éolienne du parc',
#        'investigation de le exploitant', 'pale à le consigne',
#        'éolienne de 60 m', 'vitesse du rotor', 'remplacement de tout',
#        'limite de sécurité', 'interprétation du donnée',
#        'début de matinée', 'défaillance du système',
#        'dispositif de protection', 'condition météorologique',
#        'augmentation rapide', 'position effectif', 'charge mécanique',
#        'intervention direct', 'liaison mécanique',
#        'défaillance potentiel', 'm supérieur', 'usure anormal',
#        'éolienne', 'pale', 'système', 'orientation', 'bloc', 'frein',
#        'sécurité', 'place', 'défaillance', 'rotor', 'autre', 'm',
#        'intervention', 'mât', 'exploitant', 'maintenance', 'usure',
#        'position', 'tempête', 'sol'], dtype=object)

# %%
df_all["term"] = df_all["term"].astype(str)
df_all.head()
# Out:
#      event                                 term
# 0  event-0                      Lemmatised form
# 1  event-0                  orientation du pale
# 2  event-0             bloc de frein du système
# 3  event-0                        bloc de frein
# 4  event-0  limite de conception de le éolienne

# %%
# Regrouper les termes par événement
event_terms = df_all.groupby("event")["term"].apply(list)

# Affichage rapide
event_terms.head()
# Out:
# event
# event-0      [Lemmatised form, orientation du pale, bloc de...
# event-1      [Lemmatised form, défaut lier au détecteur de ...
# event-10     [Lemmatised form, origine de le erreur de pitc...
# event-100    [Lemmatised form, parc éolien, suivi de le mor...
# event-101    [Lemmatised form, bout de pale, autre aérogéné...
# Name: term, dtype: object

# %%
# Un document = tous les termes concaténés
corpus = {
    event: " ".join(terms)
    for event, terms in event_terms.items()
}

len(corpus), list(corpus.items())[:3]
# Out:
# (285,
#  [('event-0',
éro place début machine bon porter lettre panne/casse machine.La accès au parc composer éolien mât m position contrôle interne samedi interne exploitant état général carbone régulation fibre découpage sécurité mat décalage service anormal mécanique inspection risque opération condition connaissance pale anormal préfecture 20h40 verre technicien mouvement information vent jeu complet consigne maintenancier accord mètre drone erreur du système de régulation origine origine de le erreur :une août charge de le maintenance alentour vérification tempête 40 m casse 9h27 physique capteur erreur du système pitch.A charge information à destination éolienne composer destination procédure de redémarrage rotor mi-août changement recommandation début gardiennage zéro municipal min société vérification alerte arrêté dégât commune préparation contrôle")])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words=None,
    token_pattern=r"(?u)\b\w[\w\-']+\b"
)

X = vectorizer.fit_transform(corpus.values())
events = list(corpus.keys())

X.shape
# Out:
# (285, 2222)

# %%
categories = {
    "environmental": ["oiseau", "animal", "impact", "pollution", "habitat", "bruit", "sol", "eau"],
    "economic": ["coût", "production", "arrêt", "dégât", "réparation", "maintenance", "perte"],
    "social": ["blessure", "accident", "pompiers", "sécurité", "personnel"]
}

# %%
def classify_event(terms):
    scores = {cat: 0 for cat in categories}
    
    for t in terms:
        if not isinstance(t, str):
            continue
        
        t_low = t.lower()
        
        for cat, kw in categories.items():
            if any(k in t_low for k in kw):
                scores[cat] += 1
    
    best = max(scores, key=scores.get)
    return best if scores[best] > 0 else "non-classe"

# %%
event_classes = {
    event: classify_event(terms)
    for event, terms in event_terms.items()
}

event_classes
# Out:
# {'event-0': 'social',
#  'event-1': 'environmental',
#  'event-10': 'economic',
#  'event-100': 'environmental',
#  'event-101': 'environmental',
#  'event-102': 'economic',
#  'event-103': 'environmental',
#  'event-104': 'economic',
#  'event-105': 'economic',
#  'event-106': 'economic',
#  'event-107': 'environmental',
#  'event-108': 'environmental',
#  'event-109': 'environmental',
#  'event-11': 'environmental',
#  'event-110': 'environmental',
#  'event-111': 'economic',
#  'event-112': 'environmental',
#  'event-113': 'environmental',
#  'event-114': 'environmental',
#  'event-115': 'environmental',
#  'event-116': 'environmental',
#  'event-117': 'environmental',
#  'event-118': 'economic',
#  'event-119': 'economic',
#  'event-12': 'economic',
#  'event-120': 'economic',
#  'event-121': 'environmental',
#  'event-122': 'environmental',
#  'event-123': 'economic',
#  'event-124': 'environmental',
#  'event-125': 'environmental',
#  'event-126': 'environmental',
#  'event-127': 'environmental',
#  'event-128': 'social',
#  'event-129': 'environmental',
#  'event-13': 'economic',
#  'event-130': 'environmental',
#  'event-131': 'environmental',
#  'event-132': 'environmental',
#  'event-133': 'environmental',
#  'event-134': 'non-classe',
#  'event-135': 'environmental',
#  'event-136': 'environmental',
#  'event-137': 'environmental',
#  'event-138': 'environmental',
#  'event-139': 'environmental',
#  'event-14': 'environmental',
#  'event-140': 'environmental',
#  'event-141': 'environmental',
#  'event-142': 'economic',
#  'event-143': 'environmental',
#  'event-144': 'environmental',
#  'event-145': 'environmental',
#  'event-146': 'environmental',
#  'event-147': 'environmental',
#  'event-148': 'environmental',
#  'event-149': 'social',
#  'event-15': 'environmental',
#  'event-150': 'social',
#  'event-151': 'environmental',
#  'event-152': 'environmental',
#  'event-153': 'environmental',
#  'event-154': 'economic',
#  'event-155': 'social',
#  'event-156': 'environmental',
#  'event-157': 'social',
#  'event-158': 'economic',
#  'event-159': 'environmental',
#  'event-16': 'environmental',
#  'event-160': 'non-classe',
#  'event-161': 'social',
#  'event-162': 'social',
#  'event-163': 'economic',
#  'event-164': 'environmental',
#  'event-165': 'environmental',
#  'event-166': 'environmental',
#  'event-167': 'economic',
#  'event-168': 'environmental',
#  'event-169': 'environmental',
#  'event-17': 'economic',
#  'event-170': 'environmental',
#  'event-171': 'environmental',
#  'event-172': 'environmental',
#  'event-173': 'environmental',
#  'event-174': 'environmental',
#  'event-175': 'environmental',
#  'event-176': 'environmental',
#  'event-177': 'environmental',
#  'event-178': 'economic',
#  'event-179': 'environmental',
#  'event-18': 'environmental',
#  'event-180': 'environmental',
#  'event-181': 'non-classe',
#  'event-182': 'environmental',
#  'event-183': 'environmental',
#  'event-184': 'non-classe',
#  'event-185': 'environmental',
#  'event-186': 'environmental',
#  'event-187': 'non-classe',
#  'event-188': 'non-classe',
#  'event-189': 'economic',
#  'event-19': 'social',
#  'event-190': 'economic',
#  'event-191': 'economic',
#  'event-192': 'non-classe',
#  'event-193': 'environmental',
#  'event-194': 'environmental',
#  'event-195': 'environmental',
#  'event-196': 'environmental',
#  'event-197': 'environmental',
#  'event-198': 'environmental',
#  'event-199': 'environmental',
#  'event-2': 'economic',
#  'event-20': 'economic',
#  'event-200': 'economic',
#  'event-201': 'environmental',
#  'event-202': 'environmental',
#  'event-203': 'environmental',
#  'event-204': 'economic',
#  'event-205': 'social',
#  'event-206': 'economic',
#  'event-207': 'non-classe',
#  'event-208': 'economic',
#  'event-209': 'social',
#  'event-21': 'environmental',
#  'event-210': 'economic',
#  'event-211': 'economic',
#  'event-212': 'social',
#  'event-213': 'social',
#  'event-214': 'non-classe',
#  'event-215': 'environmental',
#  'event-216': 'economic',
#  'event-217': 'environmental',
#  'event-218': 'economic',
#  'event-219': 'social',
#  'event-22': 'environmental',
#  'event-220': 'environmental',
#  'event-221': 'environmental',
#  'event-222': 'economic',
#  'event-223': 'economic',
#  'event-224': 'economic',
#  'event-225': 'economic',
#  'event-226': 'environmental',
#  'event-227': 'non-classe',
#  'event-228': 'non-classe',
#  'event-229': 'environmental',
#  'event-23': 'environmental',
#  'event-230': 'environmental',
#  'event-231': 'environmental',
#  'event-232': 'environmental',
#  'event-233': 'environmental',
#  'event-234': 'environmental',
#  'event-235': 'environmental',
#  'event-236': 'environmental',
#  'event-237': 'environmental',
#  'event-238': 'environmental',
#  'event-239': 'environmental',
#  'event-24': 'environmental',
#  'event-240': 'environmental',
#  'event-241': 'environmental',
#  'event-242': 'environmental',
#  'event-243': 'environmental',
#  'event-244': 'environmental',
#  'event-245': 'environmental',
#  'event-246': 'environmental',
#  'event-247': 'environmental',
#  'event-248': 'social',
#  'event-249': 'environmental',
#  'event-25': 'environmental',
#  'event-250': 'environmental',
#  'event-251': 'environmental',
#  'event-252': 'environmental',
#  'event-253': 'environmental',
#  'event-254': 'environmental',
#  'event-255': 'environmental',
#  'event-256': 'economic',
#  'event-257': 'environmental',
#  'event-258': 'environmental',
#  'event-259': 'environmental',
#  'event-26': 'economic',
#  'event-260': 'environmental',
#  'event-261': 'environmental',
#  'event-262': 'environmental',
#  'event-263': 'environmental',
#  'event-264': 'environmental',
#  'event-265': 'environmental',
#  'event-266': 'environmental',
#  'event-267': 'environmental',
#  'event-268': 'social',
#  'event-269': 'environmental',
#  'event-27': 'environmental',
#  'event-270': 'environmental',
#  'event-271': 'environmental',
#  'event-272': 'environmental',
#  'event-273': 'environmental',
#  'event-274': 'environmental',
#  'event-275': 'environmental',
#  'event-276': 'environmental',
#  'event-277': 'environmental',
#  'event-278': 'non-classe',
#  'event-279': 'social',
#  'event-28': 'economic',
#  'event-280': 'economic',
#  'event-281': 'non-classe',
#  'event-282': 'environmental',
#  'event-283': 'environmental',
#  'event-284': 'non-classe',
#  'event-29': 'environmental',
#  'event-3': 'economic',
#  'event-30': 'environmental',
#  'event-31': 'environmental',
#  'event-32': 'social',
#  'event-33': 'environmental',
#  'event-34': 'environmental',
#  'event-35': 'economic',
#  'event-36': 'environmental',
#  'event-37': 'environmental',
#  'event-38': 'environmental',
#  'event-39': 'environmental',
#  'event-4': 'environmental',
#  'event-40': 'environmental',
#  'event-41': 'environmental',
#  'event-42': 'economic',
#  'event-43': 'environmental',
#  'event-44': 'environmental',
#  'event-45': 'economic',
#  'event-46': 'economic',
#  'event-47': 'environmental',
#  'event-48': 'economic',
#  'event-49': 'environmental',
#  'event-5': 'economic',
#  'event-50': 'social',
#  'event-51': 'economic',
#  'event-52': 'environmental',
#  'event-53': 'social',
#  'event-54': 'social',
#  'event-55': 'environmental',
#  'event-56': 'environmental',
#  'event-57': 'environmental',
#  'event-58': 'environmental',
#  'event-59': 'environmental',
#  'event-6': 'environmental',
#  'event-60': 'economic',
#  'event-61': 'environmental',
#  'event-62': 'economic',
#  'event-63': 'social',
#  'event-64': 'economic',
#  'event-65': 'environmental',
#  'event-66': 'economic',
#  'event-67': 'environmental',
#  'event-68': 'environmental',
#  'event-69': 'environmental',
#  'event-7': 'economic',
#  'event-70': 'environmental',
#  'event-71': 'environmental',
#  'event-72': 'environmental',
#  'event-73': 'economic',
#  'event-74': 'environmental',
#  'event-75': 'environmental',
#  'event-76': 'social',
#  'event-77': 'economic',
#  'event-78': 'environmental',
#  'event-79': 'economic',
#  'event-8': 'economic',
#  'event-80': 'economic',
#  'event-81': 'environmental',
#  'event-82': 'environmental',
#  'event-83': 'environmental',
#  'event-84': 'environmental',
#  'event-85': 'environmental',
#  'event-86': 'environmental',
#  'event-87': 'environmental',
#  'event-88': 'environmental',
#  'event-89': 'economic',
#  'event-9': 'environmental',
#  'event-90': 'environmental',
#  'event-91': 'economic',
#  'event-92': 'economic',
#  'event-93': 'social',
#  'event-94': 'environmental',
#  'event-95': 'environmental',
#  'event-96': 'environmental',
#  'event-97': 'social',
#  'event-98': 'environmental',
#  'event-99': 'economic'}

# %%
pd.DataFrame.from_dict(event_classes, orient="index", columns=["class"]).head(10)
# Out:
#                    class
# event-0           social
# event-1    environmental
# event-10        economic
# event-100  environmental
# event-101  environmental
# event-102       economic
# event-103  environmental
# event-104       economic
# event-105       economic
# event-106       economic

# %%
topn = 20
feature_names = vectorizer.get_feature_names()
tfidf_means = X.mean(axis=0).A1  # moyenne TF-IDF sur tout le corpus

top_ids = tfidf_means.argsort()[::-1][:topn]
top_terms = [feature_names[i] for i in top_ids]

top_terms
# Out:
# ['de',
#  'du',
#  'le',
#  'parc',
#  'éolien',
#  'mortalité',
#  'éolienne',
#  'suivi',
#  'pale',
#  'aviaire',
#  'système',
#  'sol',
#  'espèce',
#  'cadavre',
#  'chute',
#  'milan',
#  'autre',
#  'collision',
#  'au',
#  'royal']
